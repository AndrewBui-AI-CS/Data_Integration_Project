# %%
# pip install recordlinkage

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/new_car.csv')
df.head()
# Out:
#                         _id             base_url color  \
# 0  62b46f9176a6b3537a612b48  https://bonbanh.com   Đen
# 1  62b46f9176a6b3537a612b49  https://bonbanh.com  Xanh
# 2  62b46f9176a6b3537a612b4a  https://bonbanh.com   Nâu
# 3  62b46f9176a6b3537a612b4b  https://bonbanh.com    Đỏ
# 4  62b46f9176a6b3537a612b4c  https://bonbanh.com  Xanh
#
#                       drive engine  fuel fuel_consumption  \
# 0  FWD - Dẫn động cầu trước    2.0  Xăng          L/100Km
# 1  FWD - Dẫn động cầu trước    2.4  Xăng          L/100Km
# 2    RFD - Dẫn động cầu sau    2.0  Xăng          L/100Km
# 3    RFD - Dẫn động cầu sau    2.0  Xăng          L/100Km
# 4     4WD - Dẫn động 4 bánh    2.0   Dầu          L/100Km
#
#                                                image interior_color  \
# 0  ["https://bonbanh.com/uploads/users/645334/car...      Nhiều màu
# 1  ["https://bonbanh.com/uploads/users/645334/car...            Kem
# 2  ["https://bonbanh.com/uploads/users/645334/car...            Đen
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24206 entries, 0 to 24205
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               24206 non-null  object
#  1   base_url          24206 non-null  object
#  2   color             14733 non-null  object
#  3   drive             14574 non-null  object
#  4   engine            8914 non-null   object
#  5   fuel              24029 non-null  object
#  6   fuel_consumption  8422 non-null   object
#  7   image             24206 non-null  object
#  8   interior_color    14045 non-null  object
#  9   km                17026 non-null  object
#  10  manufacturer      24187 non-null  object
#  11  mfg               24187 non-null  float64
#  12  name              24190 non-null  object
#  13  origin            20667 non-null  object
#  14  price             24190 non-null  float64
#  15  seat              22133 non-null  float64
# ...

# %%
df.columns.values
remove_fields = ['_id', 'fuel_consumption', 'km', 'source', 'time_update', 'image']
# base_url = ['https://bonbanh.com', 'https://xe.chotot.com', 'https://xe360.vn', 'https://choxeotofun.net']
# urls = ['https://xe.chotot.com', 'https://xe360.vn', 'https://choxeotofun.net']

# %%
df_truncate = df.drop(remove_fields, 1)
df_truncate.head()
# Out:
# /tmp/ipykernel_14559/1355946673.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df_truncate = df.drop(remove_fields, 1)
#               base_url color                     drive engine  fuel  \
# 0  https://bonbanh.com   Đen  FWD - Dẫn động cầu trước    2.0  Xăng
# 1  https://bonbanh.com  Xanh  FWD - Dẫn động cầu trước    2.4  Xăng
# 2  https://bonbanh.com   Nâu    RFD - Dẫn động cầu sau    2.0  Xăng
# 3  https://bonbanh.com    Đỏ    RFD - Dẫn động cầu sau    2.0  Xăng
# 4  https://bonbanh.com  Xanh     4WD - Dẫn động 4 bánh    2.0   Dầu
#
#   interior_color manufacturer     mfg  \
# 0      Nhiều màu          kia  2021.0
# 1            Kem          kia  2019.0
# 2            Đen      vinfast  2021.0
# 3            Nâu      vinfast  2019.0
# 4            Đen         ford  2020.0
#
#                                                 name              origin  \
# ...

# %%
df_truncate.shape
df_truncate.to_csv(r'/home/hoang/Desktop/truncated_data.csv', index=False)

# %%
df_truncate.drop(df_truncate.index[df_truncate['base_url'] == 'https://bonbanh.com'], inplace=True)
df_truncate.drop(df_truncate.index[df_truncate['base_url'] == 'https://xe360.vn'], inplace=True)
# df_truncate.drop(df_truncate.index[df_truncate['base_url'] == 'https://xe.chotot.com'], inplace=True)
df_truncate.drop(df_truncate.index[df_truncate['base_url'] == 'https://choxeotofun.net'], inplace=True)
# df_truncate

# %%
total_features = df_truncate.columns.to_list()
total_features
# Out:
# ['base_url',
#  'color',
#  'drive',
#  'engine',
#  'fuel',
#  'interior_color',
#  'manufacturer',
#  'mfg',
#  'name',
#  'origin',
#  'price',
#  'seat',
#  'status',
#  'transmission',
#  'type']

# %%
feature_unique_fields = {}
for i in total_features:
    feature_unique_fields[i] = df_truncate[i].unique().tolist()

# %%
feature_unique_fields
# Out:
# {'base_url': ['https://www.carmudi.vn', 'https://xe.chotot.com'],
#  'color': [nan],
#  'drive': [nan],
#  'engine': [nan],
#  'fuel': [nan, 'Xăng', 'Dầu', 'Điện', 'Động cơ Hybrid'],
#  'interior_color': [nan],
#  'manufacturer': [nan,
#   'toyota',
#   'ford',
#   'kia',
#   'vinfast',
#   'honda',
#   'mitsubishi',
#   'mazda',
#   'bmw',
#   'hyundai',
#   'lexus',
#   'nissan',
#   'chevrolet',
#   'mercedes benz',
#   'daewoo',
#   'volkswagen',
#   'isuzu',
#   'fiat',
#   'porsche',
#   'audi',
#   'suzuki',
#   'landrover',
#   'mini',
#   'maserati',
#   'smart',
#   'zotye',
#   'peugeot',
#   'subaru',
#   'mekong',
#   'citroen',
#   'jaguar',
#   'acura',
#   'mg',
#   'rolls royce',
#   'hãng khác',
#   'luxgen',
#   'ssangyong',
#   'volvo',
#   'chery',
#   'chrysler',
#   'lamborghini',
#   'bentley',
#   'sym',
#   'lincoln',
#   'renault',
#   'daihatsu',
#   'gaz',
#   'lifan',
#   'jeep',
#   'geely',
#   'infiniti',
#   'dodge',
#   'baic',
#   'proton',
# ...

# %%
# import recordlinkage
# indexer = recordlinkage.Index()
# indexer.block("base_url")
# candidate_links = indexer.index(df_truncate)
# len(candidate_links)
